# %% [markdown]
# ### Libraries Imported :

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Data Extracted from csv.file :

# %%
df = pd.read_csv('Amazon Sales data.csv')

# %% [markdown]
# ### Data UndUnderstanding:

# %%
df.head()
# Out:
#                               Region                Country        Item Type  \
# 0              Australia and Oceania                 Tuvalu        Baby Food
# 1  Central America and the Caribbean                Grenada           Cereal
# 2                             Europe                 Russia  Office Supplies
# 3                 Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                 Sub-Saharan Africa                 Rwanda  Office Supplies
#
#   Sales Channel Order Priority Order Date   Order ID  Ship Date  Units Sold  \
# 0       Offline              H  5/28/2010  669165933  6/27/2010        9925
# 1        Online              C  8/22/2012  963881480  9/15/2012        2804
# 2       Offline              L   5/2/2014  341417157   5/8/2014        1779
# 3        Online              C  6/20/2014  514321792   7/5/2014        8102
# 4       Offline              L   2/1/2013  115456712   2/6/2013        5062
#
# ...

# %%
df.tail()
# Out:
#                 Region       Country      Item Type Sales Channel  \
# 95  Sub-Saharan Africa          Mali        Clothes        Online
# 96                Asia      Malaysia         Fruits       Offline
# 97  Sub-Saharan Africa  Sierra Leone     Vegetables       Offline
# 98       North America        Mexico  Personal Care       Offline
# 99  Sub-Saharan Africa    Mozambique      Household       Offline
#
#    Order Priority  Order Date   Order ID   Ship Date  Units Sold  Unit Price  \
# 95              M   7/26/2011  512878119    9/3/2011         888      109.28
# 96              L  11/11/2011  810711038  12/28/2011        6267        9.33
# 97              C    6/1/2016  728815257   6/29/2016        1485      154.06
# 98              M   7/30/2015  559427106    8/8/2015        5767       81.73
# 99              L   2/10/2012  665095412   2/15/2012        5367      668.27
#
#     Unit Cost  Total Revenue  Total Cost  Total Profit
# ...

# %%
print('The Number of Rows',df.shape[0])
print('The Number of Columns',df.shape[1])
# Out:
# The Number of Rows 100
# The Number of Columns 14

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Region          100 non-null    object
#  1   Country         100 non-null    object
#  2   Item Type       100 non-null    object
#  3   Sales Channel   100 non-null    object
#  4   Order Priority  100 non-null    object
#  5   Order Date      100 non-null    object
#  6   Order ID        100 non-null    int64
#  7   Ship Date       100 non-null    object
#  8   Units Sold      100 non-null    int64
#  9   Unit Price      100 non-null    float64
#  10  Unit Cost       100 non-null    float64
#  11  Total Revenue   100 non-null    float64
#  12  Total Cost      100 non-null    float64
#  13  Total Profit    100 non-null    float64
# dtypes: float64(5), int64(2), object(7)
# memory usage: 11.1+ KB

# %%
df.describe()
# Out:
#            Order ID   Units Sold  Unit Price   Unit Cost  Total Revenue  \
# count  1.000000e+02   100.000000  100.000000  100.000000   1.000000e+02
# mean   5.550204e+08  5128.710000  276.761300  191.048000   1.373488e+06
# std    2.606153e+08  2794.484562  235.592241  188.208181   1.460029e+06
# min    1.146066e+08   124.000000    9.330000    6.920000   4.870260e+03
# 25%    3.389225e+08  2836.250000   81.730000   35.840000   2.687212e+05
# 50%    5.577086e+08  5382.500000  179.880000  107.275000   7.523144e+05
# 75%    7.907551e+08  7369.000000  437.200000  263.330000   2.212045e+06
# max    9.940222e+08  9925.000000  668.270000  524.960000   5.997055e+06
#
#          Total Cost  Total Profit
# count  1.000000e+02  1.000000e+02
# mean   9.318057e+05  4.416820e+05
# std    1.083938e+06  4.385379e+05
# min    3.612240e+03  1.258020e+03
# 25%    1.688680e+05  1.214436e+05
# 50%    3.635664e+05  2.907680e+05
# 75%    1.613870e+06  6.358288e+05
# max    4.509794e+06  1.719922e+06

# %% [markdown]
# ### Data Cleaning and Preprocessing:

# %%
df.isnull().sum()
# Out:
# Region            0
# Country           0
# Item Type         0
# Sales Channel     0
# Order Priority    0
# Order Date        0
# Order ID          0
# Ship Date         0
# Units Sold        0
# Unit Price        0
# Unit Cost         0
# Total Revenue     0
# Total Cost        0
# Total Profit      0
# dtype: int64

# %%
# Convert order date to datetime

df['Order Date'] = pd.to_datetime(df['Order Date'])

# %%
# Extract year and month from order date

df['Year'] = df['Order Date'].dt.year
df['Month'] = df['Order Date'].dt.month
df.head()
# Out:
#                               Region                Country        Item Type  \
# 0              Australia and Oceania                 Tuvalu        Baby Food
# 1  Central America and the Caribbean                Grenada           Cereal
# 2                             Europe                 Russia  Office Supplies
# 3                 Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                 Sub-Saharan Africa                 Rwanda  Office Supplies
#
#   Sales Channel Order Priority Order Date   Order ID  Ship Date  Units Sold  \
# 0       Offline              H 2010-05-28  669165933  6/27/2010        9925
# 1        Online              C 2012-08-22  963881480  9/15/2012        2804
# 2       Offline              L 2014-05-02  341417157   5/8/2014        1779
# 3        Online              C 2014-06-20  514321792   7/5/2014        8102
# 4       Offline              L 2013-02-01  115456712   2/6/2013        5062
#
# ...

# %% [markdown]
# ### Data Analysis :

# %%
# Calculate the number of regions:

regions = df['Region'].nunique()
print('Number of Regions:',regions)
# Out:
# Number of Regions: 7

# %% [markdown]
# #### The Number of Regions available in our dataset : 7

# %%
# Calculate the number of countries:

country = df['Country'].nunique()
print('Number of Country:',country)
# Out:
# Number of Country: 76

# %% [markdown]
# #### The Number of Country available in our dataset: 76

# %%
# Calculate the itrm Types: 

item_type = df['Item Type'].nunique()
print('The Number of Item Types:',item_type)
# Out:
# The Number of Item Types: 12

# %% [markdown]
# ####  The Number of item types available in our dataset: 12

# %%
# Calculate the total unit sold

unit_sold = df['Units Sold'].sum()
print('Total unit sold :', unit_sold)
# Out:
# Total unit sold : 512871

# %% [markdown]
# #### The total unit sold : 512871

# %%
# Calculate the total unit cost :

unit_cost = df['Unit Cost'].sum()
print('Total unit cost:', unit_cost)
# Out:
# Total unit cost: 19104.8

# %% [markdown]
# #### Total unit cost: 19104.8

# %%
# calculate the total revenue: 

total_revenue = df['Total Revenue'].sum()
print('Total revenue is:',total_revenue)
# Out:
# Total revenue is: 137348768.31

# %% [markdown]
# #### Total revenue is: 137348768.31

# %%
# calculate the total cost : 

total_cost = round(df['Total Cost'].sum(),2)
print('Total cost is:',total_cost)
# Out:
# Total cost is: 93180569.91

# %% [markdown]
# #### Total cost is: 93180569.91

# %%
# calculate the total profit:

total_profit = round(df['Total Profit'].sum(),2)
print('Total Profit is:',total_profit)
# Out:
# Total Profit is: 44168198.4

# %% [markdown]
# #### Total Profit is: 44168198.4

# %%
df.groupby(['Region','Sales Channel'])['Total Profit'].sum()
# Out:
# Region                             Sales Channel
# Asia                               Offline          3584286.33
#                                    Online           2529559.54
# Australia and Oceania              Offline          1886283.82
#                                    Online           2835876.21
# Central America and the Caribbean  Offline          2475814.99
#                                    Online            371092.86
# Europe                             Offline          5574539.91
#                                    Online           5508398.72
# Middle East and North Africa       Offline          2169081.08
#                                    Online           3592110.78
# North America                      Offline          1457942.76
# Sub-Saharan Africa                 Offline          7772777.78
#                                    Online           4410433.62
# Name: Total Profit, dtype: float64

# %% [markdown]
# /* Dominance of Offline Sales in Sub-Saharan Africa:
#
# Sub-Saharan Africa shows the highest total profit in the Offline channel at 7,772,777.78, which significantly surpasses its Online profit of 4,410,433.62. This indicates a strong preference for Offline sales in this region.
# High Online Sales in Europe:
#
# Europe has almost equal profits from both Online (5,508,398.72) and Offline channels (5,574,539.91), suggesting a balanced market presence and effective e-commerce strategy.
# Underperformance of Online Channel in Central America and the Caribbean:
#
# In Central America and the Caribbean, the Offline channel generates a high profit of 2,475,814.99 compared to only 371,092.86 for the Online channel. This disparity suggests potential growth opportunities for the Online segment.
# Strong Online Presence in Asia:
#
# In Asia, the Online channel profit is 2,529,559.54, which is quite competitive compared to Offline sales of 3,584,286.33, indicating that the Online market is well-developed and can be further leveraged.
# Balanced Sales Channels in Australia and Oceania:
#
# For Australia and Oceania, Online and Offline profits are closely matched at 2,835,876.21 and 1,886,283.82, respectively. This indicates a well-distributed sales strategy across channels.
# Significant Online Sales in the Middle East and North Africa:
#
# In the Middle East and North Africa, the Online sales channel has a higher profit (3,592,110.78) compared to Offline (2,169,081.08), showing a growing trend towards online shopping in this region.
# Limited Online Presence in North America:
#
# North America shows profit only for the Offline channel at 1,457,942.76, with no data provided for Online sales, indicating either a lack of presence or reporting in the Online channel. */

# %% [markdown]
# ### Exploratory Data Analysis (EDA)

# %%
df.head(1)
# Out:
#                   Region Country  Item Type Sales Channel Order Priority  \
# 0  Australia and Oceania  Tuvalu  Baby Food       Offline              H
#
#   Order Date   Order ID  Ship Date  Units Sold  Unit Price  Unit Cost  \
# 0 2010-05-28  669165933  6/27/2010        9925      255.28     159.42
#
#    Total Revenue  Total Cost  Total Profit  Year  Month
# 0      2533654.0   1582243.5      951410.5  2010      5

# %%
# Year wise sales:

year_wise = df.groupby('Year')['Total Revenue'].mean()


plt.figure(figsize=(8, 3))
sns.barplot(x=year_wise.index, y=year_wise.values)
plt.title('Average Sales By Year')
plt.xlabel('Year')
plt.ylabel('Average Total Revenue')
plt.xticks(rotation=45)
plt.show()

# %%
# Pie chart of total profit in region wise:

plt.figure(figsize=(6,6))
region_TotalRevenue = df.groupby('Region')['Total Profit'].mean()
plt.pie(region_TotalRevenue,startangle=90,labels=region_TotalRevenue.index,autopct='%1.1f%%')
plt.title('Average_Profit_In_Region_Wise')
# Out:
# Text(0.5, 1.0, 'Average_Profit_In_Region_Wise')

# %%
# group total revenue by item type:

Total_Revenue_ItemType = df.groupby('Item Type')['Total Revenue'].sum()

# %%
# Bar Chart for total revenue by item type:

plt.figure(figsize=(8,3))
Total_Revenue_ItemType.plot(kind='bar')
plt.xlabel('Item Type')
plt.ylabel('Total Revenue')
plt.title('Average Revenue by Product type')
plt.grid(axis='y')

# %%
# group total revenue by sales channel:

Total_Revenue_SalesChannel = df.groupby('Sales Channel')['Total Revenue'].mean()

# %%
# Bar chart for total revenue by item type:

plt.figure(figsize=(6,6))
plt.tight_layout()
Total_Revenue_SalesChannel.plot(kind='pie',autopct='%1.1f%%',startangle=90)
plt.title('Total Revenue By Sales Channel')
plt.show()

# %%
df.head(1)
# Out:
#                   Region Country  Item Type Sales Channel Order Priority  \
# 0  Australia and Oceania  Tuvalu  Baby Food       Offline              H
#
#   Order Date   Order ID  Ship Date  Units Sold  Unit Price  Unit Cost  \
# 0 2010-05-28  669165933  6/27/2010        9925      255.28     159.42
#
#    Total Revenue  Total Cost  Total Profit  Year  Month
# 0      2533654.0   1582243.5      951410.5  2010      5

# %%
# Create a Pie chart for a donut chart:

Region_unitsold = df.groupby('Region')['Units Sold'].sum()
plt.figure(figsize=(6,6))
Region_unitsold.plot(kind='pie',labels=Region_unitsold.index, autopct='%1.1f%%',shadow=True, startangle=140)

# Drow a circle at the centre of the pie chart:

cntr_circle = plt.Circle((0,0),(0.70),fc='white')
fig = plt.gcf()
fig.gca().add_artist(cntr_circle)

# Equal aspect fatio ensures that pie is drawn as a circle

plt.title('Units Sold By Regions')
plt.axis('equal')
plt.show()

# %%
# Group units sold by year and month:

Year_Month_Units_Sold = df.groupby(['Year','Month'])['Units Sold'].sum()

# %%
# Create a Bar Chart for units sold by year and month

plt.figure(figsize=(10,6))
Year_Month_Units_Sold.plot(kind='bar')
plt.ylabel('Year and Month')
plt.xlabel('Units Sold')
plt.tight_layout()
plt.grid(axis='y')

# %%
# group total cost by sales channel

totalCost_SalesChannel = df.groupby('Sales Channel')['Total Cost'].sum()

# %%
totalCost_SalesChannel = df.groupby('Sales Channel')['Total Cost'].sum()

# Bar chart for total cost by sales channel

plt.figure(figsize=(6,6))
totalCost_SalesChannel.plot(kind='pie',autopct='%1.1f%%',startangle=90)
plt.title('Total Cost By Sales Channel')
plt.tight_layout()

# %% [markdown]
# ## Model Selection:

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans, AgglomerativeClustering, DBSCAN
from sklearn.metrics import silhouette_score

# %%
numerical_features = df[['Units Sold', 'Total Profit']]

# %%
scaler = StandardScaler()
scaled_features = scaler.fit_transform(numerical_features)

# %%
pd.DataFrame(scaled_features, columns=['Units Sold', 'Total Profit']).head()
# Out:
#    Units Sold  Total Profit
# 0    1.724988      1.168192
# 1   -0.836083     -0.442948
# 2   -1.204725     -0.497510
# 3    1.069345     -0.967494
# 4   -0.023992      0.452390

# %% [markdown]
# ## Clustering Models:
#
#
# #### K-Means Clustering

# %%
# Trying out different number of clusters (K)
wcss = []
for i in range(1, 11):  
    kmeans = KMeans(n_clusters=i, init='k-means++', max_iter=300, n_init=10, random_state=0)
    kmeans.fit(scaled_features)
    wcss.append(kmeans.inertia_)

# Plotting the Elbow Graph
plt.plot(range(1, 11), wcss)
plt.title('Elbow Method')
plt.xlabel('Number of clusters (K)')
plt.ylabel('WCSS')
plt.show()
# Out:
# C:\Users\Hp\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1036: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
# Applying K-Means to the dataset with optimal number of clusters 
kmeans = KMeans(n_clusters=3, init='k-means++', max_iter=300, n_init=10, random_state=0)
clusters = kmeans.fit_predict(scaled_features)

# %%
df['Cluster'] = clusters

# %%
df[['Units Sold', 'Total Profit', 'Cluster']].head()
# Out:
#    Units Sold  Total Profit  Cluster
# 0        9925     951410.50        1
# 1        2804     248406.36        2
# 2        1779     224598.75        2
# 3        8102      19525.82        0
# 4        5062     639077.50        0

# %%
# Visualizing the clusters
plt.figure(figsize=(10,6))

plt.scatter(scaled_features[clusters == 0, 0], scaled_features[clusters == 0, 1], s=100, c='red', label='Cluster 1')
plt.scatter(scaled_features[clusters == 1, 0], scaled_features[clusters == 1, 1], s=100, c='blue', label='Cluster 2')
plt.scatter(scaled_features[clusters == 2, 0], scaled_features[clusters == 2, 1], s=100, c='green', label='Cluster 3')

# Plot centroids
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s=300, c='yellow', label='Centroids')
plt.title('Clusters of Units Sold and Total Profit')
plt.xlabel('Units Sold (Scaled)')
plt.ylabel('Total Profit (Scaled)')
plt.legend()
plt.show()

# %%
# Analyze the mean values of each cluster
cluster_analysis = df.groupby('Cluster').mean()
print(cluster_analysis)
# Out:
#              Order ID   Units Sold  Unit Price   Unit Cost  Total Revenue  \
# Cluster
# 0        5.446879e+08  6242.936170  200.223404  139.812766   1.065786e+06
# 1        4.679726e+08  8132.315789  459.781053  310.623158   3.629739e+06
# 2        6.179479e+08  1909.970588  280.287941  195.051765   5.379942e+05
#
#            Total Cost  Total Profit         Year     Month
# Cluster
# 0        7.279731e+05  3.378126e+05  2013.361702  6.063830
# 1        2.433338e+06  1.196401e+06  2013.105263  6.578947
# 2        3.744829e+05  1.635113e+05  2013.117647  6.352941

# %%
# Count the number of items sold in each cluster
cluster_item_type = df.groupby('Cluster')['Item Type'].value_counts()
print(cluster_item_type)
# Out:
# Cluster  Item Type
# 0        Beverages          8
#          Clothes            8
#          Personal Care      7
#          Fruits             6
#          Office Supplies    4
#          Baby Food          3
#          Household          3
#          Cereal             2
#          Meat               2
#          Vegetables         2
#          Cosmetics          1
#          Snacks             1
# 1        Cosmetics          9
#          Household          4
#          Baby Food          2
#          Office Supplies    2
#          Cereal             1
#          Clothes            1
# 2        Office Supplies    6
#          Cereal             4
#          Clothes            4
#          Fruits             4
#          Vegetables         4
#          Cosmetics          3
#          Personal Care      3
#          Baby Food          2
#          Household          2
#          Snacks             2
# Name: Item Type, dtype: int64

# %%
# Calculate silhouette score
silhouette_avg = silhouette_score(scaled_features, clusters)
print(f'Silhouette Score: {silhouette_avg}')
# Out:
# Silhouette Score: 0.4543481616824938
